# %% [markdown]
# #Fetching Data

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %%
import requests
import pandas as pd


url = 'https://api.coingecko.com/api/v3/coins/markets'
params = {
    'vs_currency': 'usd',
    'order': 'market_cap_desc',
    'per_page': 50,
    'page': 1,
    'sparkline': False
}

response = requests.get(url, params=params)
data = response.json()

df = pd.DataFrame(data, columns=[
    'name', 'symbol', 'current_price', 'market_cap',
    'total_volume', 'price_change_percentage_24h'
])
print(df)
# Out:
#                  name  symbol  current_price     market_cap  total_volume  \
# 0             Bitcoin     btc   94985.000000  1884974904900   38869945612
# 1            Ethereum     eth    2584.610000   311459067133   23914078309
# 2              Tether    usdt       0.999917   141941958565   78158720386
# 3                 XRP     xrp       2.380000   137594259162    4893516891
# 4                 BNB     bnb     644.930000    94129568538    1436048015
# 5              Solana     sol     191.920000    93693568178    4133823294
# 6                USDC    usdc       0.999896    56070510940    5724558728
# 7            Dogecoin    doge       0.251406    37187853616    1623238630
# 8             Cardano     ada       0.765172    27499332939    1398708891
# 9   Lido Staked Ether   steth    2583.560000    24249977913     129206236
# 10               TRON     trx       0.241220    20769349550     839388439
# 11    Wrapped Bitcoin    wbtc   94933.000000    12265207117     678261374
# 12          Chainlink    link      17.920000    11441753240     673490917
# 13      Wrapped stETH  wsteth    3082.090000    10339267532      81676704
# 14          Avalanche    avax      24.810000    10219917190     358158818
# 15                Sui     sui       3.170000     9811846706    1310931235
# 16            Stellar     xlm       0.314423     9617212313     355202014
# 17          Shiba Inu    shib       0.000016     9373524091     316780019
# 18            Toncoin     ton       3.670000     9149927801     174269507
# 19          LEO Token     leo       9.830000     9084374129        527603
# 20           Litecoin     ltc     115.020000     8681919017    1330715428
# 21               USDS    usds       1.001000     8458382051      15686630
# 22             Hedera    hbar       0.216841     8299900912     297667073
# 23        Hyperliquid    hype      23.410000     7815905264     141522525
# 24               WETH    weth    2584.100000     7627713775     974619849
# 25           Polkadot     dot       4.850000     7380005081     278521385
# 26       Bitget Token     bgb       5.760000     6917693602     374849475
# 27       Bitcoin Cash     bch     325.770000     6463232638     172477361
# 28        Ethena USDe    usde       0.999872     6014837898      87366811
# 29            Uniswap     uni       9.270000     5566246467     325836130
# 30             MANTRA      om       5.710000     5551610037     310635194
# 31       Wrapped eETH   weeth    2740.650000     5245507055      13613727
# 32               Ondo    ondo       1.340000     4236607487     354475715
# 33             Monero     xmr     221.600000     4090568324      52626577
# 34      WhiteBIT Coin     wbt      27.200000     3914636304      20826694
# 35               Pepe    pepe       0.000009     3899892890     967883784
# 36      NEAR Protocol    near       3.150000     3713432546     281641804
# 37               Aave    aave     236.740000     3568565348     290050883
# 38                Dai     dai       0.999707     3470057751     261014820
# 39             Mantle     mnt       1.014000     3412122485     123572104
# 40  Internet Computer     icp       6.990000     3358422377     111049144
# 41              Aptos     apt       5.840000     3357647338     240733030
# 42              sUSDS   susds       1.038000     3249405079        441087
# 43          Bittensor     tao     383.340000     3148560445     212528714
# 44   Ethereum Classic     etc      20.230000     3047219176     124117051
# 45                OKB     okb      50.110000     3004579261       8653265
# 46     Official Trump   trump      14.710000     2940965925     866720300
# 47               Gate      gt      21.740000     2735840173      15062733
# 48            VeChain     vet       0.032554     2636421232      58106302
# 49     POL (ex-MATIC)     pol       0.304990     2610593905      91039172
#
#     price_change_percentage_24h
# 0                      -1.98717
# 1                      -2.74354
# 2                      -0.01797
# 3                      -3.39851
# 4                       1.77941
# 5                      -3.71026
# 6                      -0.01007
# 7                      -3.31308
# 8                      -3.22917
# 9                      -2.73415
# 10                     -1.36142
# 11                     -1.73035
# 12                     -6.65615
# 13                     -2.88654
# 14                     -5.32701
# 15                     -9.28949
# 16                     -5.02689
# 17                      0.48501
# 18                     -2.90896
# 19                      0.29226
# 20                     -9.11415
# 21                      0.09013
# 22                     -8.60656
# 23                     -3.91346
# 24                     -2.68183
# 25                     -2.78851
# 26                     -9.63278
# 27                     -3.55351
# 28                      0.03397
# 29                     -4.60991
# 30                     -5.54605
# 31                     -2.42245
# 32                     -4.46496
# 33                      0.15445
# 34                     -1.56896
# 35                     -6.87142
# 36                     -5.34046
# 37                     -5.51368
# 38                     -0.03306
# 39                     -2.26144
# 40                     -3.32939
# 41                     -2.06238
# 42                      0.34475
# 43                     -9.20008
# 44                     -2.68649
# 45                     -2.16355
# 46                     -6.27078
# 47                     -0.67499
# 48                     -4.69416
# 49                     -2.84342

# %% [markdown]
# #data analysis

# %%
top_5 = df.nlargest(5, 'market_cap')
print("Top 5 Cryptocurrencies by Market Cap:")
print(top_5[['name', 'market_cap']])

average_price = df['current_price'].mean()
print(f"Average Price of Top 50 Cryptocurrencies: ${average_price:.2f}")

highest_change = df.loc[df['price_change_percentage_24h'].idxmax()]
lowest_change = df.loc[df['price_change_percentage_24h'].idxmin()]

print("Highest 24-Hour Percentage Price Change:")
print(highest_change[['name', 'price_change_percentage_24h']])

print("Lowest 24-Hour Percentage Price Change:")
print(lowest_change[['name', 'price_change_percentage_24h']])
# Out:
# Top 5 Cryptocurrencies by Market Cap:
#        name     market_cap
# 0   Bitcoin  1884974904900
# 1  Ethereum   311459067133
# 2    Tether   141941958565
# 3       XRP   137594259162
# 4       BNB    94129568538
# Average Price of Top 50 Cryptocurrencies: $4117.67
# Highest 24-Hour Percentage Price Change:
# name                               BNB
# price_change_percentage_24h    1.77941
# Name: 4, dtype: object
# Lowest 24-Hour Percentage Price Change:
# name                           Bitget Token
# price_change_percentage_24h        -9.63278
# Name: 26, dtype: object

# %% [markdown]
# #live excel sheet

# %%
import requests
import pandas as pd
from openpyxl import Workbook
import time

def fetch_data():
    url = 'https://api.coingecko.com/api/v3/coins/markets'
    params = {
        'vs_currency': 'usd',
        'order': 'market_cap_desc',
        'per_page': 50,
        'page': 1,
        'sparkline': False
    }
    response = requests.get(url, params=params)
    data = response.json()
    df = pd.DataFrame(data, columns=[
        'name', 'symbol', 'current_price', 'market_cap',
        'total_volume', 'price_change_percentage_24h'
    ])
    return df

def update_excel(df):
    with pd.ExcelWriter('crypto_data.xlsx', engine='openpyxl') as writer:
        df.to_excel(writer, index=False, sheet_name='Top 50 Cryptocurrencies')

while True:
    df = fetch_data()
    update_excel(df)
    print("Excel sheet updated.")
    time.sleep(300)
# Out:
# Excel sheet updated.
